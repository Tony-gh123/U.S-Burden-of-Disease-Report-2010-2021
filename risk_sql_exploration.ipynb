# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sqlite3
import re
import numpy as np
# Run pip install ipython-sql
# %load_ext sql

# %sql sqlite:///database/risk.sqlite

# Run the next line if error
# %config SqlMagic.style = '_DEPRECATED_DEFAULT' 

# %sql SELECT name from sqlite_master where type='table';
# Out:
#  * sqlite:///database/risk.sqlite
# Done.
# [('methods_table1',),
#  ('methods_table2',),
#  ('methods_table4',),
#  ('methods_table5',),
#  ('methods_table6',),
#  ('methods_table7',),
#  ('methods_table8',),
#  ('methods_table9',),
#  ('table1',),
#  ('table1_global',),
#  ('table2',),
#  ('table2_global',),
#  ('table3',),
#  ('table3_global',),
#  ('table4',),
#  ('table4_global',),
#  ('table5',),
#  ('table6',),
#  ('table_index',),
#  ('usa_table1',)]

# %%
# %%sql
# alter table IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S1_Y2024M05D14 rename to methods_table1;
# alter table IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S2_Y2024M05D14 rename to methods_table2;
# alter table IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S4_Y2024M05D14 rename to methods_table4;
# alter table IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S5_Y2024M05D14 rename to methods_table5;
# alter table IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S6_Y2024M05D14 rename to methods_table6;
# alter table IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S7_Y2024M05D14 rename to methods_table7;
# alter table IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S8_Y2024M05D14 rename to methods_table8;
# alter table IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S9_Y2024M05D14 rename to methods_table9;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S1_ALL_LOCATIONS_Y2024M05D14 rename to table1;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S1_GLOBAL_Y2024M05D14 rename to table1_global;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S2_ALL_LOCATIONS_Y2024M05D14 rename to table2;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S2_GLOBAL_Y2024M05D14 rename to table2_global;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S3_ALL_LOCATIONS_Y2024M05D14 rename to table3;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S3_GLOBAL_Y2024M05D14 rename to table3_global;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S4_ALL_LOCATIONS_Y2024M05D14 rename to table4;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S4_GLOBAL_Y2024M05D14 rename to table4_global;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S5_Y2024M05D14 rename to table5;
# alter table IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S6_Y2024M05D14 rename to table6;
# alter table IHME_GBD_2021_RISK_1990_2021_TABLE_INDEX_Y2024M05D14 rename to table_index;
# Out:
#  * sqlite:///database/risk.sqlite
# (sqlite3.OperationalError) no such table: IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S1_Y2024M05D14
# [SQL: alter table IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S1_Y2024M05D14 rename to methods_table1;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql select * from table_index;
# Out:
#  * sqlite:///database/risk.sqlite
# Done.
# [('Methods Appendix Table S2. Types of Comparative Risk Assessments (CRA) based on the time perspective and the nature of the counterfactual level or distribution of exposure', 'IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S2_Y2024M05D14.XLSX'),
#  ('Methods Appendix Table S3. GATHER checklist', 'IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S3_Y2024M05D14.PDF'),
#  ('Methods Appendix Table S4. GBD Location Hierarchy with Levels', 'IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S4_Y2024M05D14.XLSX'),
#  ('Methods Appendix Table S5. SDI 1990-2021', 'IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S5_Y2024M05D14.XLSX'),
#  ('Methods Appendix Table S6. Mediation Factor Matrix', 'IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S6_Y2024M05D14.XLSX'),
#  ('Methods Appendix Table S7. Status of risk–outcome pairs considered for inclusion in GBD 2021: included in both GBD 2019 and GBD 2021, added in GBD 2021, or removed in GBD 2021', 'IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S7_Y2024M05D14.XLSX'),
#  ('Methods Appendix Table S8. Status of mediated risk–outcome pairs considered for inclusion in GBD 2021: included in both GBD 2019 and GBD 2021, added in GBD 2021, or removed in GBD 2021', 'IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S8_Y2024M05D14.XLSX'),
#  ('Methods Appendix Table S9. TMREL changes compared to GBD 2019.', 'IHME_GBD_2021_RISK_1990_2021_METHODS_APPENDIX_TABLE_S9_Y2024M05D14.XLSX'),
#  (None, None),
#  ('Supplementary Results Appendix', 'File'),
#  ('SR Appendix Table S1. Death PAFs, all-age death counts, all-age death rates (per 100 000), death, age-standardised death rate (per 100 000), DALY PAF ... (75 characters truncated) ... ) for each risk factor and outcome for both sexes combined in 1990, 2000, 2010, and 2021, by geography. Percentage change for 1990-2021 and 2000-2021', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S1_ALL_LOCATIONS_Y2024M05D14.XLSX'),
#  ('SR Appendix Table S1. Global death PAFs, all-age death counts, all-age death rates (per 100 000), death, age-standardised death rate (per 100 000), D ... (68 characters truncated) ... e (per 100 000) for each risk factor and outcome for both sexes combined in 1990, 2000, 2010, and 2021. Percentage change for 1990-2021 and 2000-2021', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S1_GLOBAL_Y2024M05D14.XLSX'),
#  ('SR Appendix Table S2. Death PAFs, all-age death counts, all-age death rates (per 100 000), death, age-standardised death rate (per 100 000), DALY PAF ... (124 characters truncated) ...  combined in 1990, 2000, 2010, and 2021, excluding one- and two-star risk-outcome pairs, by geography. Percentage change for 1990-2021 and 2000-2021.', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S2_ALL_LOCATIONS_Y2024M05D14.XLSX'),
#  ('SR Appendix Table S2. Global death PAFs, all-age death counts, all-age death rates (per 100 000), death, age-standardised death rate (per 100 000), D ... (117 characters truncated) ... for both sexes combined in 1990, 2000, 2010, and 2021, excluding one- and two-star risk-outcome pairs. Percentage change for 1990-2021 and 2000-2021.', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S2_GLOBAL_Y2024M05D14.XLSX'),
#  ('SR Appendix Table S3. Age-standardised Summary Exposure Values (SEVs) for risk factors and percentage change, by sex, 1990, 2000, 2010 and 2021, and geography', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S3_ALL_LOCATIONS_Y2024M05D14.XLSX'),
#  ('SR Appendix Table S3. Age-standardised Summary Exposure Values (SEVs) for risk factors and percentage change, by sex, 1990, 2000, 2010 and 2021', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S3_GLOBAL_Y2024M05D14.XLSX'),
#  ('SR Appendix Table S4. All-age PAFs attributable to the joint distribution of all risk factors, both sexes combined for each GBD Level 1, Level 2, and Level 3 cause and all causes in 2021, by geography', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S4_ALL_LOCATIONS_Y2024M05D14.XLSX'),
#  ('SR Appendix Table S4. All-age PAFs attributable to the joint distribution of all risk factors, both sexes combined for each GBD Level 1, Level 2, and Level 3 cause and all causes in 2021, by geography', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S4_GLOBAL_Y2024M05D14.XLSX'),
#  ('SR Appendix Table S5. Relative risks used by age and sex for each outcome for unsafe water, unsafe sanitation, iron deficiency, high alcohol use, low ... (109 characters truncated) ... partner violence, childhood sexual abuse, chewing tobacco, low birth weight and short gestation, particulate matter pollution, lead exposure in blood', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S5_Y2024M05D14.XLSX'),
#  ('SR Appendix Table S6. Risk-outcome scores and global DALY counts for all risk-outcome pairs submitted to the burden of proof analysis, 2021', 'IHME_GBD_2021_RISK_1990_2021_RESULTS_APPENDIX_TABLE_S6_Y2024M05D14.XLSX')]

# %%
# %sql select * from table3 limit 3;
# Out:
#  * sqlite:///database/risk.sqlite
# Done.
# [(' All risk factors', 'Aceh', '31·0\n(28·9  –  33·6)', '30·2\n(27·9  –  33·1)', '29·2\n(26·4  –  32·3)', '28·3\n(25·2  –  31·5)', '27·2\n(23·6  –  30·5)', '-2·6\n(-5·8  –  -0·2)', '-3·5\n(-9·7  –  0·2)', '-10·0\n(-20·0  –  -3·7)', '-6·8\n(-17·4  –  -0·1)', '-4·0\n(-13·4  –  3·0)', '28·9\n(27·1  –  30·8)', '27·9\n(25·7  –  30·0)', '27·3\n(24·4  –  29·4)', '26·7\n(24·0  –  29·0)', '26·6\n(23·8  –  29·0)', '-3·4\n(-8·2  –  -0·3)', '-2·3\n(-8·6  –  2·7)', '-4·8\n(-12·8  –  2·0)', '-2·5\n(-9·9  –  4·7)', '-0·4\n(-8·4  –  8·2)', '30·0\n(28·2  –  32·1)', '29·1\n(27·1  –  31·2)', '28·3\n(26·1  –  30·4)', '27·5\n(25·3  –  29·9)', '26·9\n(24·5  –  29·2)', '-3·0\n(-6·1  –  -0·7)', '-2·9\n(-7·1  –  0·3)', '-7·5\n(-14·3  –  -2·3)', '-4·7\n(-11·7  –  0·2)', '-2·3\n(-8·4  –  3·2)'),
#  ('  Environmental/occupational risks', 'Aceh', '43·0\n(34·5  –  50·8)', '36·0\n(28·0  –  44·0)', '31·0\n(24·0  –  37·8)', '26·3\n(20·3  –  33·9)', '23·9\n(18·3  –  30·1)', '-16·2\n(-26·8  –  -5·5)', '-13·9\n(-24·9  –  -1·7)', '-33·8\n(-46·3  –  -17·5)', '-23·0\n(-37·1  –  -7·5)', '-9·4\n(-25·8  –  10·2)', '40·6\n(32·7  –  47·8)', '34·0\n(26·5  –  41·7)', '29·1\n(22·5  –  35·3)', '24·5\n(19·0  –  31·3)', '22·1\n(16·6  –  28·1)', '-16·3\n(-26·9  –  -6·5)', '-14·2\n(-24·2  –  -3·6)', '-34·8\n(-47·0  –  -20·4)', '-24·0\n(-37·6  –  -8·4)', '-9·8\n(-25·9  –  10·1)', '41·8\n(33·6  –  49·2)', '35·0\n(27·1  –  42·8)', '30·1\n(23·1  –  36·5)', '25·4\n(19·7  –  32·5)', '23·0\n(17·5  –  29·1)', '-16·3\n(-27·0  –  -6·0)', '-14·1\n(-24·4  –  -2·2)', '-34·3\n(-46·5  –  -19·2)', '-23·5\n(-37·6  –  -7·6)', '-9·6\n(-26·2  –  10·6)'),
#  ('   Unsafe water, sanitation, and handwashing', 'Aceh', '48·3\n(32·5  –  65·1)', '34·4\n(20·3  –  48·2)', '27·4\n(14·7  –  40·4)', '24·4\n(12·0  –  37·4)', '21·7\n(11·0  –  33·6)', '-28·8\n(-44·6  –  -13·7)', '-20·4\n(-37·2  –  -2·4)', '-37·0\n(-56·1  –  -12·2)', '-20·9\n(-40·2  –  1·3)', '-11·3\n(-23·4  –  2·2)', '48·3\n(32·5  –  65·1)', '34·4\n(20·3  –  48·2)', '27·4\n(14·7  –  40·4)', '24·4\n(12·0  –  37·4)', '21·7\n(11·0  –  33·6)', '-28·8\n(-44·6  –  -13·7)', '-20·4\n(-37·2  –  -2·4)', '-37·0\n(-56·1  –  -12·2)', '-20·9\n(-40·2  –  1·3)', '-11·3\n(-23·4  –  2·2)', '48·3\n(32·5  –  65·1)', '34·4\n(20·3  –  48·2)', '27·4\n(14·7  –  40·4)', '24·4\n(12·0  –  37·4)', '21·7\n(11·0  –  33·6)', '-28·8\n(-44·6  –  -13·7)', '-20·4\n(-37·2  –  -2·4)', '-37·0\n(-56·1  –  -12·2)', '-20·9\n(-40·2  –  1·3)', '-11·3\n(-23·4  –  2·2)')]

# %% [markdown]
# ### Check to see the correlation of Diseases of Interest and risk factors
#
# Ischemic heart disease, Ischemic stroke, Hypertensive heart disease, Intracerebral hemorrhage, covid-19,
# ALzheimer's disease and other dementias, Chronic obstructive pulmonary diease, Tracheal & Bronchus and lung cancer, colon and rectum cancer, prostate cancer, breast cancer, diabetes mellitus type 2, opiod use disorders.
#
# The joint PAFs: how much of each cause of death (and DALYs, YLLs, YLDs) is attributable to all risks combined.

# %% [markdown]
# ### Table 4

# %%
# %%sql
# select * from table4 where Location = 'USA'
# and cause like '%prostate%'
# Out:
#  * sqlite:///database/risk.sqlite
# Done.
# [('Prostate cancer', 'USA', '2·98\n(1·15  –  5·55)', '3·67\n(1·52  –  6·50)', '4·14\n(1·75  –  7·01)', '3·53\n(1·45  –  6·33)')]

# %%
# %%sql disease_factor <<
# select * from table4 where Location = 'USA'
# and cause like "%Chronic obstructive pulmonary disease%"
# Out:
#  * sqlite:///database/risk.sqlite
# Done.
# Returning data to local variable disease_factor

# %%
df = disease_factor.DataFrame()
print(df.to_markdown(index=False))
# Out:
# | Cause                                 | Location   | Deaths          | DALYs           | YLDs            | YLLs            |
# |                                       |            | 2021            | 2021            | 2021            | 2021            |
# |:--------------------------------------|:-----------|:----------------|:----------------|:----------------|:----------------|
# | Chronic obstructive pulmonary disease | USA        | 55·4            | 55·8            | 49·1            | 58·4            |
# |                                       |            | (47·1  –  63·0) | (47·4  –  63·6) | (39·7  –  57·9) | (50·3  –  66·1) |

# %% [markdown]
# ### Table 6

# %% [markdown]
# ### Identifying Risk Name v. Outcome Name for top 10 diseases found.

# %%
# %sql select * from table6 where [Outcome Name] like '%Ischae%';
# Out:
#  * sqlite:///database/risk.sqlite
# Done.
# [('High systolic blood pressure', 'Ischaemic heart disease', 0.7, 5.0, '94000 \n(75600 to 111000)', 'Standard', None, 'Metabolic'),
#  ('Kidney dysfunction', 'Ischaemic heart disease', 0.45, 4.0, '26100 \n(18900 to 33400)', 'Standard', None, 'Metabolic'),
#  ('High LDL cholesterol', 'Ischaemic heart disease', 0.32, 3.0, '66700 \n(47500 to 87000)', 'Standard', None, 'Metabolic'),
#  ('Particulate matter pollution', 'Ischaemic heart disease', 0.26, 3.0, '54700 \n(41700 to 67400)', 'Standard', None, 'Environmental/ Occupational'),
#  ('High LDL cholesterol', 'Ischaemic stroke', 0.2, 3.0, '21000 \n(7410 to 34700)', 'Standard', None, 'Metabolic'),
#  ('Smoking', 'Ischaemic heart disease', 0.19, 3.0, '35500 \n(30500 to 40700)', 'Standard', None, 'Behavioural '),
#  ('Low physical activity', 'Ischaemic heart disease', 0.18, 3.0, '3900 \n(1770 to 6120)', 'Standard', None, 'Behavioural '),
#  ('Diet low in whole grains', 'Ischaemic heart disease', 0.17, 3.0, '27100 \n(16900 to 36700)', 'Standard', None, 'Behavioural '),
#  ('Low physical activity', 'Ischaemic stroke', 0.15, 3.0, '3360 \n(907 to 6300)', 'Standard', None, 'Behavioural '),
#  ('Diet low in vegetables', 'Ischaemic stroke', 0.15, 3.0, '1190 \n(636 to 1830)', 'Standard', None, 'Behavioural '),
#  ('High fasting plasma glucose', 'Ischaemic stroke', 0.15, 3.0, '12400 \n(9590 to 15400)', 'Standard', None, 'Metabolic'),
#  ('Diet low in fruits', 'Ischaemic stroke', 0.15, 3.0, '2060 \n(1090 to 3270)', 'Standard', None, 'Behavioural '),
#  ('High fasting plasma glucose', 'Ischaemic heart disease', 0.15, 3.0, '25900 \n(22300 to 29800)', 'Standard', None, 'Metabolic'),
#  ('High body-mass index', 'Ischaemic heart disease', 0.13, 2.0, '23900 \n(9470 to 38300)', 'Standard', None, 'Metabolic'),
#  ('Diet low in vegetables', 'Ischaemic heart disease', 0.13, 2.0, '6120 \n(3030 to 9490)', 'Standard', None, 'Behavioural '),
#  ('Diet low in fibre', 'Ischaemic heart disease', 0.12, 2.0, '11500 \n(6160 to 16400)', 'Standard', None, 'Behavioural '),
#  ('Diet low in nuts and seeds', 'Ischaemic heart disease', 0.11, 2.0, '16300 \n(4810 to 26200)', 'Standard', None, 'Behavioural '),
#  ('Diet low in seafood omega-3 fatty acids', 'Ischaemic heart disease', 0.1, 2.0, '15500 \n(3100 to 25900)', 'Standard', None, 'Behavioural '),
#  ('Non-optimal temperature', 'Ischaemic heart disease', 0.08, 2.0, '12400 \n(9160 to 17600)', 'Standard', None, 'Environmental/ Occupational'),
#  ('Diet low in fruits', 'Ischaemic heart disease', 0.06, 2.0, '15900 (3490 to 25800)', 'Standard', None, 'Behavioural '),
#  ('Secondhand smoke', 'Ischaemic heart disease', 0.06, 2.0, '9700 (7260 to 12100)', 'Standard', None, 'Behavioural '),
#  ('High body-mass index', 'Ischaemic stroke', 0.05, 2.0, '4440 (649 to 8650)', 'Standard', None, 'Metabolic'),
#  ('Diet high in trans fatty acids', 'Ischaemic heart disease', 0.03, 2.0, '2490 (242 to 4780)', 'Standard', None, 'Behavioural '),
#  ('Diet high in processed meat', 'Ischaemic heart disease', 0.01, 2.0, '1900 (763 to 2950)', 'Standard', None, 'Behavioural '),
#  ('Diet high in red meat', 'Ischaemic heart disease', 0.01, 2.0, '4410 (-225 to 8960)', 'Standard', None, 'Behavioural '),
#  ('Diet low in fibre', 'Ischaemic stroke', 0.01, 2.0, '948 (-40.2 to 1920)', 'Standard', None, 'Behavioural '),
#  ('High alcohol use', 'Ischaemic heart disease', 0.0, 2.0, '-3310 (-5150 to -848)', 'Standard', None, 'Behavioural '),
#  ('Diet high in sugar-sweetened beverages', 'Ischaemic heart disease', 0.0, 1.0, '200 (-47.2 to 436)', 'Standard', None, 'Behavioural '),
#  ('High alcohol use', 'Ischaemic stroke', -0.01, 1.0, '3870 (-603 to 9620)', 'Standard', None, 'Behavioural '),
#  ('Diet high in red meat', 'Ischaemic stroke', -0.02, 1.0, '117 (-133 to 1160)', 'Standard', None, 'Behavioural '),
#  ('Diet low in legumes', 'Ischaemic heart disease', -0.06, 1.0, '9160 (-7630 to 23000)', 'Standard', None, 'Behavioural '),
#  ('Diet low in whole grains', 'Ischaemic stroke', -0.07, 1.0, '3130 (-3180 to 8780)', 'Standard', None, 'Behavioural '),
#  ('Diet low in omega-6 polyunsaturated fatty acids', 'Ischaemic heart disease', -0.17, 1.0, '17900 (-56000 to 65900)', 'Standard', None, 'Behavioural ')]

# %%
# %%sql disease <<
# select [Risk Name], [Outcome Name], [Risk-Outcome Score], [Star Rating], [2021 DALYS (in thousands)], [Risk Type]
# from table6
# where [Outcome Name] like '%Ischaemic heart disease%'
# and [Star Rating] >= 2;
# Out:
#  * sqlite:///database/risk.sqlite
# Done.
# Returning data to local variable disease

# %%
df = disease.DataFrame()
print(df.to_markdown(index=False))
# Out:
# | Risk Name                               | Outcome Name            |   Risk-Outcome Score |   Star Rating | 2021 DALYS (in thousands)   | Risk Type                   |
# |:----------------------------------------|:------------------------|---------------------:|--------------:|:----------------------------|:----------------------------|
# | High systolic blood pressure            | Ischaemic heart disease |                 0.7  |             5 | 94000                       | Metabolic                   |
# |                                         |                         |                      |               | (75600 to 111000)           |                             |
# | Kidney dysfunction                      | Ischaemic heart disease |                 0.45 |             4 | 26100                       | Metabolic                   |
# |                                         |                         |                      |               | (18900 to 33400)            |                             |
# | High LDL cholesterol                    | Ischaemic heart disease |                 0.32 |             3 | 66700                       | Metabolic                   |
# |                                         |                         |                      |               | (47500 to 87000)            |                             |
# | Particulate matter pollution            | Ischaemic heart disease |                 0.26 |             3 | 54700                       | Environmental/ Occupational |
# |                                         |                         |                      |               | (41700 to 67400)            |                             |
# | Smoking                                 | Ischaemic heart disease |                 0.19 |             3 | 35500                       | Behavioural                 |
# |                                         |                         |                      |               | (30500 to 40700)            |                             |
# | Low physical activity                   | Ischaemic heart disease |                 0.18 |             3 | 3900                        | Behavioural                 |
# |                                         |                         |                      |               | (1770 to 6120)              |                             |
# | Diet low in whole grains                | Ischaemic heart disease |                 0.17 |             3 | 27100                       | Behavioural                 |
# |                                         |                         |                      |               | (16900 to 36700)            |                             |
# | High fasting plasma glucose             | Ischaemic heart disease |                 0.15 |             3 | 25900                       | Metabolic                   |
# |                                         |                         |                      |               | (22300 to 29800)            |                             |
# | High body-mass index                    | Ischaemic heart disease |                 0.13 |             2 | 23900                       | Metabolic                   |
# |                                         |                         |                      |               | (9470 to 38300)             |                             |
# | Diet low in vegetables                  | Ischaemic heart disease |                 0.13 |             2 | 6120                        | Behavioural                 |
# |                                         |                         |                      |               | (3030 to 9490)              |                             |
# | Diet low in fibre                       | Ischaemic heart disease |                 0.12 |             2 | 11500                       | Behavioural                 |
# |                                         |                         |                      |               | (6160 to 16400)             |                             |
# | Diet low in nuts and seeds              | Ischaemic heart disease |                 0.11 |             2 | 16300                       | Behavioural                 |
# |                                         |                         |                      |               | (4810 to 26200)             |                             |
# | Diet low in seafood omega-3 fatty acids | Ischaemic heart disease |                 0.1  |             2 | 15500                       | Behavioural                 |
# |                                         |                         |                      |               | (3100 to 25900)             |                             |
# | Non-optimal temperature                 | Ischaemic heart disease |                 0.08 |             2 | 12400                       | Environmental/ Occupational |
# |                                         |                         |                      |               | (9160 to 17600)             |                             |
# | Diet low in fruits                      | Ischaemic heart disease |                 0.06 |             2 | 15900 (3490 to 25800)       | Behavioural                 |
# | Secondhand smoke                        | Ischaemic heart disease |                 0.06 |             2 | 9700 (7260 to 12100)        | Behavioural                 |
# | Diet high in trans fatty acids          | Ischaemic heart disease |                 0.03 |             2 | 2490 (242 to 4780)          | Behavioural                 |
# | Diet high in processed meat             | Ischaemic heart disease |                 0.01 |             2 | 1900 (763 to 2950)          | Behavioural                 |
# | Diet high in red meat                   | Ischaemic heart disease |                 0.01 |             2 | 4410 (-225 to 8960)         | Behavioural                 |
# | High alcohol use                        | Ischaemic heart disease |                 0    |             2 | -3310 (-5150 to -848)       | Behavioural                 |

# %% [markdown]
# ### Table 3

# %% [markdown]
# ### Indetifying change in uniquely identified risk names.

# %% [markdown]
# High body-mass index, Particulate matter pollution, Smoking, Low physical activity, Diet low in fibre, Diet low in whole grains, Diet high in sugar-sweetened beverages, Diet high in processed meat, High alcohol use, Diet low in fruits, Diet high in red meat, Diet low in calcium, High fasting plasma glucose, Diet low in milk, Diet low in vegetables, Non-optimal temperature, High LDL cholesterol, High systolic blood pressure, Kidney dysfunction

# %%
# %%sql
# SELECT * FROM table3
# WHERE Location = 'USA'
# AND (
#     [Risk Name] LIKE '%High body-mass index%'
#     OR [Risk Name] LIKE '%Particulate matter pollution%'
#     OR [Risk Name] LIKE '%Smoking%'
#     OR [Risk Name] LIKE '%Low physical activity%'
#     OR [Risk Name] LIKE '%Diet low in fibre%'
#     OR [Risk Name] LIKE '%Diet low in whole grains%'
#     OR [Risk Name] LIKE '%Diet high in sugar-sweetened beverages%'
#     OR [Risk Name] LIKE '%Diet high in processed meat%'
#     OR [Risk Name] LIKE '%High alcohol use%'
#     OR [Risk Name] LIKE '%Diet low in fruits%'
#     OR [Risk Name] LIKE '%Diet high in red meat%'
#     OR [Risk Name] LIKE '%Diet low in calcium%'
#     OR [Risk Name] LIKE '%High fasting plasma glucose%'
#     OR [Risk Name] LIKE '%Diet low in milk%'
#     OR [Risk Name] LIKE '%Diet low in vegetables%'
#     OR [Risk Name] LIKE '%Non-optimal temperature%'
#     OR [Risk Name] LIKE '%High LDL cholesterol%'
#     OR [Risk Name] LIKE '%High systolic blood pressure%'
#     OR [Risk Name] LIKE '%Kidney dysfunction%'
# ) limit 2;
# Out:
#  * sqlite:///database/risk.sqlite
# Done.
# [('    Particulate matter pollution', 'USA', '13·6\n(5·1  –  23·7)', '12·3\n(8·9  –  16·3)', '7·6\n(4·8  –  11·1)', '6·1\n(3·4  –  9·4)', '4·7\n(2·2  –  7·7)', '-9·7\n(-46·7  –  104·4)', '-37·8\n(-47·0  –  -30·7)', '-62·0\n(-76·2  –  -51·3)', '-38·9\n(-55·0  –  -29·4)', '-23·8\n(-37·1  –  -16·7)', '13·0\n(4·9  –  22·8)', '11·8\n(8·5  –  15·7)', '7·3\n(4·6  –  10·7)', '5·9\n(3·3  –  9·0)', '4·5\n(2·1  –  7·4)', '-9·6\n(-46·5  –  104·0)', '-37·7\n(-46·9  –  -30·6)', '-62·0\n(-76·2  –  -51·3)', '-39·0\n(-55·0  –  -29·5)', '-23·8\n(-37·1  –  -16·7)', '13·3\n(5·0  –  23·3)', '12·0\n(8·7  –  16·0)', '7·5\n(4·7  –  10·9)', '6·0\n(3·4  –  9·2)', '4·6\n(2·1  –  7·5)', '-9·6\n(-46·6  –  104·2)', '-37·8\n(-47·0  –  -30·6)', '-62·0\n(-76·2  –  -51·3)', '-38·9\n(-55·0  –  -29·5)', '-23·8\n(-37·1  –  -16·7)'),
#  ('     Ambient particulate matter pollution', 'USA', '20·6\n(8·0  –  35·8)', '18·5\n(13·9  –  23·6)', '11·5\n(7·4  –  16·1)', '9·2\n(5·2  –  13·6)', '7·0\n(3·3  –  11·2)', '-10·2\n(-47·7  –  108·5)', '-38·2\n(-47·5  –  -31·1)', '-62·4\n(-76·4  –  -51·9)', '-39·2\n(-55·2  –  -29·6)', '-23·9\n(-37·2  –  -16·8)', '20·8\n(8·1  –  36·0)', '18·7\n(14·0  –  23·8)', '11·5\n(7·5  –  16·2)', '9·2\n(5·2  –  13·7)', '7·0\n(3·3  –  11·2)', '-10·1\n(-47·6  –  108·7)', '-38·2\n(-47·5  –  -31·1)', '-62·5\n(-76·4  –  -51·9)', '-39·2\n(-55·2  –  -29·7)', '-23·9\n(-37·2  –  -16·8)', '20·7\n(8·0  –  35·9)', '18·6\n(14·0  –  23·7)', '11·5\n(7·4  –  16·2)', '9·2\n(5·2  –  13·7)', '7·0\n(3·3  –  11·2)', '-10·2\n(-47·7  –  108·6)', '-38·2\n(-47·5  –  -31·1)', '-62·4\n(-76·4  –  -51·9)', '-39·2\n(-55·2  –  -29·6)', '-23·9\n(-37·2  –  -16·8)')]

# %%
# %%sql risk_name_changes <<
# select [Risk Name], [Percentage change 2010-2021 Male], [Percentage change 2010-2021 Female], [Percentage change 2010-2021 Both], [Location]
# from table3
# where Location = 'USA'
# AND (
#     [Risk Name] LIKE '%High body-mass index%'
#     OR [Risk Name] LIKE '%Particulate matter pollution%'
#     OR [Risk Name] LIKE '%Smoking%'
#     OR [Risk Name] LIKE '%Low physical activity%'
#     OR [Risk Name] LIKE '%Diet low in fibre%'
#     OR [Risk Name] LIKE '%Diet low in whole grains%'
#     OR [Risk Name] LIKE '%Diet high in sugar-sweetened beverages%'
#     OR [Risk Name] LIKE '%Diet high in processed meat%'
#     OR [Risk Name] LIKE '%High alcohol use%'
#     OR [Risk Name] LIKE '%Diet low in fruits%'
#     OR [Risk Name] LIKE '%Diet high in red meat%'
#     OR [Risk Name] LIKE '%Diet low in calcium%'
#     OR [Risk Name] LIKE '%High fasting plasma glucose%'
#     OR [Risk Name] LIKE '%Diet low in milk%'
#     OR [Risk Name] LIKE '%Diet low in vegetables%'
#     OR [Risk Name] LIKE '%Non-optimal temperature%'
#     OR [Risk Name] LIKE '%High LDL cholesterol%'
#     OR [Risk Name] LIKE '%High systolic blood pressure%'
#     OR [Risk Name] LIKE '%Kidney dysfunction%'
# )
# Out:
#  * sqlite:///database/risk.sqlite
# Done.
# Returning data to local variable risk_name_changes

# %%
df = risk_name_changes.DataFrame()

for col in df.columns:
    df[col] = df[col].map(lambda x: str(x).replace('\n', ' ') if pd.notnull(x) else x)

df_clean = df[df["Risk Name"].astype(str).str.strip().ne("")]

for col in [
    "Percentage change 2010-2021 Male",
    "Percentage change 2010-2021 Female",
    "Percentage change 2010-2021 Both"
]:
    df_clean[col] = df_clean[col].str.extract(r'([-+]?\d+·\d+)')

print(df_clean.to_markdown(index=False))
# Out:
# | Risk Name                              | Percentage change 2010-2021 Male   | Percentage change 2010-2021 Female   | Percentage change 2010-2021 Both   | Location   |
# |:---------------------------------------|:-----------------------------------|:-------------------------------------|:-----------------------------------|:-----------|
# | Particulate matter pollution           | -38·9                              | -39·0                                | -38·9                              | USA        |
# | Ambient particulate matter pollution   | -39·2                              | -39·2                                | -39·2                              | USA        |
# | Non-optimal temperature                | -11·1                              | -11·2                                | -11·1                              | USA        |
# | Smoking                                | -14·9                              | -15·6                                | -15·2                              | USA        |
# | High alcohol use                       | -1·4                               | 3·1                                  | 1·4                                | USA        |
# | Diet low in fruits                     | 3·2                                | 4·0                                  | 3·4                                | USA        |
# | Diet low in vegetables                 | -2·1                               | -0·8                                 | -1·7                               | USA        |
# | Diet low in whole grains               | 1·7                                | -0·3                                 | 0·6                                | USA        |
# | Diet low in milk                       | -2·4                               | -0·8                                 | -1·3                               | USA        |
# | Diet high in red meat                  | 0·4                                | -0·1                                 | 0·1                                | USA        |
# | Diet high in processed meat            | -0·1                               | -5·5                                 | -3·0                               | USA        |
# | Diet high in sugar-sweetened beverages | 0·9                                | -2·1                                 | -0·8                               | USA        |
# | Diet low in calcium                    | -2·5                               | -1·3                                 | -1·7                               | USA        |
# | Low physical activity                  | 20·4                               | 9·4                                  | 12·8                               | USA        |
# | High fasting plasma glucose            | 14·1                               | 18·5                                 | 16·0                               | USA        |
# | High LDL cholesterol                   | -4·0                               | -2·5                                 | -3·3                               | USA        |
# | High systolic blood pressure           | 32·0                               | 49·8                                 | 38·9                               | USA        |
# | High body-mass index                   | 6·4                                | 9·2                                  | 7·8                                | USA        |
# | Kidney dysfunction                     | 3·6                                | 4·2                                  | 3·9                                | USA        |

# %%
# Rename columns so they're consistent for melting
df_clean = df_clean.rename(columns={
    "Percentage change 2010-2021 Male": "Male",
    "Percentage change 2010-2021 Female": "Female",
    "Percentage change 2010-2021 Both": "Both"
})

# Only melt the sex columns
df_melted = df_clean.melt(
    id_vars="Risk Name",
    value_vars=["Male", "Female", "Both"],
    var_name="Sex",
    value_name="Percentage Change"
)

# Convert 'Percentage Change' to float
df_melted["Percentage Change"] = (
    df_melted["Percentage Change"]
    .str.replace("·", ".", regex=False)
    .astype(float)
)

# Order risks by "Both" percentage change for readability
order = df_clean.sort_values("Both")["Risk Name"]

# Plot
plt.figure(figsize=(10, 8))
sns.barplot(
    data=df_melted,
    y="Risk Name",
    x="Percentage Change",
    hue="Sex",
    order=order,
    palette="Set2"
)

plt.axvline(0, color="black", linewidth=0.8)
plt.title("Percentage Change in Risk Factors (2010–2021, USA)", fontsize=14, weight="bold", pad=20)
plt.xlabel("Percentage Change (%)")
plt.ylabel("Risk Factor")
plt.legend(title="Sex", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()
